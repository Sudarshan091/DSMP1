# %% [markdown]
# # 1. Python Output

# %%
# Python is a case sensitive language
print('Hello Sudarshan')
# Out:
# Hello Sudarshan

# %%
print('Amitabh Bachchan')
# Out:
# Amitabh Bachchan

# %%
print(salman khan)
# Out:
#   File "<ipython-input-3-0713073d8d88>", line 1
#     print(salman khan)
#                     ^
# SyntaxError: invalid syntax

# %%
print(7)
# Out:
# 7

# %%
print(7.7)
# Out:
# 7.7

# %%
print(True)
# Out:
# True

# %%
print('Hello',1,4.5,True)
# Out:
# Hello 1 4.5 True

# %%
print('sudarshan'" " 'dob'" ",2,9,2004,sep='/')
# Out:
# sudarshan dob /2/9/2004

# %%
print('Hello',1,4.5,True,sep='/')
# Out:
# Hello/1/4.5/True

# %%
print('hello')
print('world')
# Out:
# hello
# world

# %%
print('hello',end='-')
print('world')
# Out:
# hello-world

# %% [markdown]
# # 2. Data Types

# %%
# Integer
print(8)
# 1*10^308
print(1e309)
# Out:
# 8
# inf

# %%
# Decimal/Float
print(8.55)
print(1.7e309)
# Out:
# 8.55
# inf

# %%
# Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
# Text/String
print('Hello World')
# Out:
# Hello World

# %%
# complex
print(5+6j)
# Out:
# (5+6j)

# %%
# List-> C-> Array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# Sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# Dictionary
print({'name':'Nitish','gender':'Male','weight':70})
# Out:
# {'name': 'Nitish', 'gender': 'Male', 'weight': 70}

# %%
# type
type([1,2,3])
# Out:
# list

# %% [markdown]
# # 3. Variables

# %%
# Static Vs Dynamic Typing
# Static Vs Dynamic Binding
# stylish declaration techniques

# %%
# C/C++
name = 'sudarshan'
print(name)

a = 15
b = 6

print(a + b)
# Out:
# sudarshan
# 21

# %%
# Dynamic Typing
a = 5
# Static Typing
# int a = 5

# %%
# Dynamic Binding
a = 5
print(a)
a = 'nitish'
print(a)

# Static Binding
# int a = 5
# Out:
# 5
# nitish

# %%
a = 1
b = 2
c = 3
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c= 5
print(a,b,c)
# Out:
# 5 5 5

# %%
sudarshan=natwar=sarth="jai narain college of technology "
student1= sudarshan
student2 = natwar
student3 = sarth
print(student1 + "_" + student2 + "_" + student3)
# Out:
# jai narain college of technology _jai narain college of technology _jai narain college of technology

# %%
print(student1 + '\n' + student2 + '\n' + student3)
# Out:
# jai narain college of technology
# jai narain college of technology
# jai narain college of technology

# %%
student_list = [student1, student2, student3]
print(student_list)
# Out:
# ['jai narain college of technology ', 'jai narain college of technology ', 'jai narain college of technology ']

# %% [markdown]
# # Comments

# %%
# this is a comment
# second line
a = 4
b = 6 # like th is
# second comment
print(a+b)
# Out:
# 10

# %% [markdown]
# # 4. Keywords & Identifiers

# %%
# Keywords

# %%
# Identifiers
# You can't start with a digit
name1 = 'Nitish'
print(name1)
# You can use special chars -> _
_ = 'ntiish'
print(_)
# identiers can not be keyword
# Out:
# Nitish
# ntiish

# %% [markdown]
# # Temp Heading

# %% [markdown]
# #Sudarshan heading just for testing

# %%
print('this is a heading just for testing that how we can create a heading like this ')
# Out:
# this is a heading just for testing that how we can create a heading like this

# %% [markdown]
# # 5. User Input

# %%
# Static Vs Dynamic
input('Enter Email: ')
# Out:
# Enter Email: choudharysudarshan091@gmail.com
# 'choudharysudarshan091@gmail.com'

# %%
# take input from users and store them in a variable
num1 = int(input("enter the first number:"))
num2 = int(input("enter the second number: "))
sum= num1 + num2
print(sum)
print(type(num1))
# Out:
# enter the first number:98
# enter the second number: 89
# 187
# <class 'int'>

# %% [markdown]
# # 6. Type Conversion

# %%
print(4*" " 'sudarshan')
# Out:
#  sudarshan sudarshan sudarshan sudarshan

# %%
a = 5
b = int('10') # Changed 'sudarshan' to '10' for demonstration

d = a + b
print(d)
# Out:
# 15

# %%
# Implicit Vs Explicit
print(5+5.6)
print(type(5),type(5.6))

# This line caused the error: print(4 + '4')
# To fix for arithmetic addition:
print(4 + int('4'))
# To fix for string concatenation:
# print(str(4) + '4')
# Out:
# 10.6
# <class 'int'> <class 'float'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3295153562.py in <cell line: 0>()
#       3 print(type(5),type(5.6))
#       4
# ----> 5 print(4 + '4')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Explicit
# str -> int
str(4+5j)

# int to str
str(5)

# float
float(4)
# Out:
# 4.0

# %% [markdown]
# # 7. Literals

# %%
a = 0b1010 #Binary Literals
b = 100 #Decimal Literal
c = 0o310 #Octal Literal
d = 0x12c #Hexadecimal Literal

#Float Literal
float_1 = 10.5
float_2 = 1.5e2 # 1.5 * 10^2
float_3 = 1.5e-3 # 1.5 * 10^-3

#Complex Literal
x = 3.14j

print(a, b, c, d)
print(float_1, float_2,float_3)
print(x, x.imag, x.real)
# Out:
# 10 100 200 300
# 10.5 150.0 0.0015
# 3.14j 3.14 0.0

# %%
# binary
x = 3.14j
print(x.imag)
# Out:
# 3.14

# %%
string = 'This is Python'
strings = "This is Python"
char = "C"
multiline_str = """This is a multiline string with more than one line code."""
unicode = u"\U0001f600\U0001F606\U0001F923"
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is Python
# This is Python
# C
# This is a multiline string with more than one line code.
# 😀😆🤣
# raw \n string

# %%
a = True + 4
b = False + 10

print("a:", a)
print("b:", b)
# Out:
# a: 5
# b: 10

# %%
k = None
a = 5
b = 6
print('Program exe')
# Out:
# Program exe

# %% [markdown]
# # 8. Operators

# %%
# Arithmetic
# Relational
# Logical
# Bitwise
# Assignment
# Membership

# %% [markdown]
# # 9. If-Else
