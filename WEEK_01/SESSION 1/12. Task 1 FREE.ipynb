# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
# Write your code here
print('Data','Science','Mentorship','Program',sep='-' , end="-separated-")
print('By','CampusX',sep='-')
# Out:
# Data-Science-Mentorship-Program-separated-By-CampusX

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
# Write your code here
celcius= float(input("enter the celcius that you want to convert: ")) #in degree
fahrenhite = (1.8 * celcius)+32
print (fahrenhite)
# Out:
# 170.6

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
# # Write your code here
# num1 = int(input("enter first number: "))
# num2 = int(input("enter second number: "))
# # Swap num1 and num2 without using tuple unpacking
# num1 = num1 + num2
# num2 = num1 - num2
# num1 = num1 - num2
a = int(input("enter the first number "))
b = int(input("enter the second number "))
temp = a 
a=b 
b= temp 
print(a)
print(b)
# Out:
# 3
# 2

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
#2d formula distnace 

x1 = int(input("enter the x coordinate of first point:"))
x2 = int(input("enter the x coordinate of second point:"))
y1 = int(input("enter the y coordinate of first point:"))
y2 = int(input("enter the y coordinate of second output:"))

distance = ((x2-x1)**2 + (y2-y1)**2)**0.5
print(round(distance,2))
# Out:
# 1.41

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
# write code here

principle = float(input("enter the priciple amount "))
rate = float(input("enter the rate of interest"))
period = int(input("entee the time period in year"))
simple_interest = (principle * rate * period)/100
print(simple_interest)
# Out:
# 1000.0

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
# Write your code here


heads = int(input("heads -> "))
legs = int(input("legs -> "))

# Logic: dogs = (legs - 2 * heads) / 2
dogs = (legs - 2 * heads) / 2
chickens = heads - dogs

print("dogs ->", int(dogs))
print("chicken ->", int(chickens))
# Out:
# dogs -> 383
# chicken -> -338

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
# Write your code here
n = int(input("enter the nmber:"))
# sum of squares of first n natural number 
sum= n*(n+1)*(2*n+1)/6
print(sum)
# Out:
# 30.0

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
# Write your code 
a1=int(7)
a2=int(13)
# from this series we get commo difference = 6
d=int(6)
#if we want the 65th term of this series it can be determined by An FORMULA = a+(n-1)d
n=int(65)
nth_term = a1+(n-1)*d
print(nth_term)
# Out:
# 391

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
# Write your code here
import math 
# a1 is the numerator of first fraction 
# a2 is the numerator of second fraction 
#b1 and b2 are similar to a1 but here these are denominator for first and second fraction 
a1,a2 = 5, 7
b1,b2 = 9 , 12

lcm = math.lcm(b1,b2)
r1,r2 = lcm//b1 , lcm//b2
num = (a1*r1)+(a2*r2)
den = lcm
print("The sum of these two fraction is", end=":")
print(num,den,sep="/")
# Out:
# The sum of these two fraction is:41/36

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
# Write your code here
import math 

#we have milk tank dimensions 
l , b , h = 10 , 19 , 10 

volume_of_milk = l*b*h

h1 = 5
r = 2
volume_of_glass = math.pi*(r)**2*h1
no_of_glass = int(volume_of_milk/volume_of_glass)

print(no_of_glass)
# Out:
# 30
