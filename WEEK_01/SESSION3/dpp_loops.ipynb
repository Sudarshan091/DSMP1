# %%
# the output of below python code segment is ___
a,b=1,3
for i in range(a,b):
    for j in range(b,a,-1):
        print(i+j,end=',')
# Out:
# 4,3,5,4,

# %%
# the final value of result is ___
result=1
for x in range(result,4,2):
    result+=1
    for y in range(result):
        result+=2
        print(result)
# Out:
# 4
# 6
# 9
# 11
# 13
# 15
# 17
# 19
# 21

# %%
for i in range(5,2,-1):
    i=10
    for j in range(1,3):
        i=i+j
print(i)
# Out:
# 13

# %%
#  what will be final ans value from the below code?
a=1
b=4
ans=1
while a<4:
    ans=ans+1
    while b>1:
        if b<=2:
            break
        ans=ans+b+a
        b=b-1
        a=a+2
    print(ans)
# Out:
# 13
